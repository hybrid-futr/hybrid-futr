# %%
from pybaseball import statcast

# %%
data = statcast()
# Out:
# start_dt 2022-10-11
# end_dt 2022-10-12
# ...
# This is a large query, it may take a moment to complete
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:04<00:00,  2.04s/it]

# %%
data.head()
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1077         SI 2022-10-11           93.2           2.77           6.11
# 1137         SI 2022-10-11           94.1           2.76           6.14
# 577          SL 2022-10-11           84.5          -3.55           4.48
# 592          SL 2022-10-11           84.6          -3.46           4.46
# 618          SL 2022-10-11           83.9          -3.47           4.53
#
#        player_name  batter  pitcher    events      description  ...  \
# 1077   Ray, Robbie  670541   592662  home_run    hit_into_play  ...
# 1137   Ray, Robbie  670541   592662       NaN             foul  ...
# 577   Sewald, Paul  665161   623149    single    hit_into_play  ...
# 592   Sewald, Paul  665161   623149       NaN     blocked_ball  ...
# 618   Sewald, Paul  665161   623149       NaN  swinging_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# ...
